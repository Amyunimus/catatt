# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
sns.set(style="white")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
ext = '_all_balanced'

precue_pic1_array_list = []
precue_pic2_array_list = []
precue_pic3_array_list = []
precue_pic4_array_list = []
precue_pic5_array_list = []
precue_pic6_array_list = []

subject_list = ['sub002','sub003','sub005','sub006','sub011','sub012','sub013',
                'sub014','sub015','sub016','sub017','sub018']

subject_list = ['sub002','sub003','sub004','sub005','sub006','sub007','sub009','sub010','sub011','sub012','sub013',
                'sub014','sub015','sub016','sub017','sub018','sub020']

subject_list = ['sub002']



for subject in subject_list:
    precue_pic1_array_list_sample = []
    precue_pic2_array_list_sample = []
    precue_pic3_array_list_sample = []
    precue_pic4_array_list_sample = []
    precue_pic5_array_list_sample = []
    precue_pic6_array_list_sample = []
    
    for sample in range(10):
        try:
            d = np.load('classification_output/'+subject+'_precue_picture1'+ext+'_'+str(sample)+'.npy')
            precue_pic1_array_list_sample.append(stats.zscore(d))
        except IOError: #sub010 has no first image
            print subject,"has not file",subject+'_precue_picture1'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_precue_picture2'+ext+'_'+str(sample)+'.npy')
            precue_pic2_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_precue_picture2'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_precue_picture3'+ext+'_'+str(sample)+'.npy')
            precue_pic3_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_precue_picture3'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_precue_picture4'+ext+'_'+str(sample)+'.npy')
            precue_pic4_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_precue_picture4'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_precue_picture5'+ext+'_'+str(sample)+'.npy')
            precue_pic5_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_precue_picture5'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_precue_picture6'+ext+'_'+str(sample)+'.npy')
            precue_pic6_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_precue_picture6'+ext+'_'+str(sample)+'.npy'
            pass
    pic1 = np.average(precue_pic1_array_list_sample, axis=0)
    pic2 = np.average(precue_pic2_array_list_sample, axis=0)
    pic3 = np.average(precue_pic3_array_list_sample, axis=0)
    pic4 = np.average(precue_pic4_array_list_sample, axis=0)
    pic5 = np.average(precue_pic5_array_list_sample, axis=0)
    pic6 = np.average(precue_pic6_array_list_sample, axis=0)
    
    
    if pic1.shape:
        precue_pic1_array_list.append(pic1)
    if pic2.shape:
        precue_pic2_array_list.append(pic2)
    if pic3.shape:
        precue_pic3_array_list.append(pic3)
    if pic4.shape:
        precue_pic4_array_list.append(pic4)
    if pic5.shape:
        precue_pic5_array_list.append(pic5)
    if pic6.shape:
        precue_pic6_array_list.append(pic6)
# Out:
# sub002 has not file sub002_precue_picture1_all_balanced_0.npy
# sub002 has not file sub002_precue_picture2_all_balanced_0.npy
# sub002 has not file sub002_precue_picture3_all_balanced_0.npy
# sub002 has not file sub002_precue_picture4_all_balanced_0.npy
# sub002 has not file sub002_precue_picture5_all_balanced_0.npy
# sub002 has not file sub002_precue_picture6_all_balanced_0.npy
# sub002 has not file sub002_precue_picture1_all_balanced_1.npy
# sub002 has not file sub002_precue_picture2_all_balanced_1.npy
# sub002 has not file sub002_precue_picture3_all_balanced_1.npy
# sub002 has not file sub002_precue_picture4_all_balanced_1.npy
# sub002 has not file sub002_precue_picture5_all_balanced_1.npy
# sub002 has not file sub002_precue_picture6_all_balanced_1.npy
# sub002 has not file sub002_precue_picture1_all_balanced_2.npy
# sub002 has not file sub002_precue_picture2_all_balanced_2.npy
# sub002 has not file sub002_precue_picture3_all_balanced_2.npy
# sub002 has not file sub002_precue_picture4_all_balanced_2.npy
# sub002 has not file sub002_precue_picture5_all_balanced_2.npy
# sub002 has not file sub002_precue_picture6_all_balanced_2.npy
# sub002 has not file sub002_precue_picture1_all_balanced_3.npy
# sub002 has not file sub002_precue_picture2_all_balanced_3.npy
# sub002 has not file sub002_precue_picture3_all_balanced_3.npy
# sub002 has not file sub002_precue_picture4_all_balanced_3.npy
# sub002 has not file sub002_precue_picture5_all_balanced_3.npy
# sub002 has not file sub002_precue_picture6_all_balanced_3.npy
# sub002 has not file sub002_precue_picture1_all_balanced_4.npy
# sub002 has not file sub002_precue_picture2_all_balanced_4.npy
# sub002 has not file sub002_precue_picture3_all_balanced_4.npy
# sub002 has not file sub002_precue_picture4_all_balanced_4.npy
# sub002 has not file sub002_precue_picture5_all_balanced_4.npy
# sub002 has not file sub002_precue_picture6_all_balanced_4.npy
# sub002 has not file sub002_precue_picture1_all_balanced_5.npy
# sub002 has not file sub002_precue_picture2_all_balanced_5.npy
# sub002 has not file sub002_precue_picture3_all_balanced_5.npy
# sub002 has not file sub002_precue_picture4_all_balanced_5.npy
# sub002 has not file sub002_precue_picture5_all_balanced_5.npy
# sub002 has not file sub002_precue_picture6_all_balanced_5.npy
# sub002 has not file sub002_precue_picture1_all_balanced_6.npy
# sub002 has not file sub002_precue_picture2_all_balanced_6.npy
# sub002 has not file sub002_precue_picture3_all_balanced_6.npy
# sub002 has not file sub002_precue_picture4_all_balanced_6.npy
# sub002 has not file sub002_precue_picture5_all_balanced_6.npy
# sub002 has not file sub002_precue_picture6_all_balanced_6.npy
# sub002 has not file sub002_precue_picture1_all_balanced_7.npy
# sub002 has not file sub002_precue_picture2_all_balanced_7.npy
# sub002 has not file sub002_precue_picture3_all_balanced_7.npy
# sub002 has not file sub002_precue_picture4_all_balanced_7.npy
# sub002 has not file sub002_precue_picture5_all_balanced_7.npy
# sub002 has not file sub002_precue_picture6_all_balanced_7.npy
# sub002 has not file sub002_precue_picture1_all_balanced_8.npy
# sub002 has not file sub002_precue_picture2_all_balanced_8.npy
# sub002 has not file sub002_precue_picture3_all_balanced_8.npy
# sub002 has not file sub002_precue_picture4_all_balanced_8.npy
# sub002 has not file sub002_precue_picture5_all_balanced_8.npy
# sub002 has not file sub002_precue_picture6_all_balanced_8.npy
# sub002 has not file sub002_precue_picture1_all_balanced_9.npy
# sub002 has not file sub002_precue_picture2_all_balanced_9.npy
# sub002 has not file sub002_precue_picture3_all_balanced_9.npy
# sub002 has not file sub002_precue_picture4_all_balanced_9.npy
# sub002 has not file sub002_precue_picture5_all_balanced_9.npy
# sub002 has not file sub002_precue_picture6_all_balanced_9.npy
# /home/predatt/emiwar/local/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
[item.shape for item in precue_pic1_array_list]
# Out:
# []

# %%
a_pic1 = np.average(precue_pic1_array_list, axis=0)
err_pic1 = stats.sem(precue_pic1_array_list, axis=0)
a_pic2 = np.average(precue_pic2_array_list, axis=0)
err_pic2 = stats.sem(precue_pic2_array_list, axis=0)
a_pic3 = np.average(precue_pic3_array_list, axis=0)
err_pic3 = stats.sem(precue_pic3_array_list, axis=0)
a_pic4 = np.average(precue_pic4_array_list, axis=0)
err_pic4 = stats.sem(precue_pic4_array_list, axis=0)
a_pic5 = np.average(precue_pic5_array_list, axis=0)
err_pic5 = stats.sem(precue_pic5_array_list, axis=0)
a_pic6 = np.average(precue_pic6_array_list, axis=0)
err_pic6 = stats.sem(precue_pic6_array_list, axis=0)

# %%
y_precue_pic1 = a_pic1.diagonal()
y_precue_pic2 = a_pic2.diagonal()
y_precue_pic3 = a_pic3.diagonal()
y_precue_pic4 = a_pic4.diagonal()
y_precue_pic5 = a_pic5.diagonal()
y_precue_pic6 = a_pic6.diagonal()



plt.figure()
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic1)#, yerr=err_pic1.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic2)#, yerr=err_pic2.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic3)#, yerr=err_pic3.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic4)#, yerr=err_pic4.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic5)#, yerr=err_pic5.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic6)#, yerr=err_pic6.diagonal())
# Out:
# <Container object of 3 artists>

# %%
ext = '_all'

noprecue_pic1_array_list = []
noprecue_pic2_array_list = []
noprecue_pic3_array_list = []
noprecue_pic4_array_list = []
noprecue_pic5_array_list = []
noprecue_pic6_array_list = []


for subject in subject_list:
    noprecue_pic1_array_list_sample = []
    noprecue_pic2_array_list_sample = []
    noprecue_pic3_array_list_sample = []
    noprecue_pic4_array_list_sample = []
    noprecue_pic5_array_list_sample = []
    noprecue_pic6_array_list_sample = []
    
    for sample in range(10):
        try:
            d = np.load('classification_output/'+subject+'_noprecue_picture1'+ext+'_'+str(sample)+'.npy')
            noprecue_pic1_array_list_sample.append(stats.zscore(d))
        except IOError: #sub010 has no first image
            print subject,"has not file",subject+'_noprecue_picture1'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_noprecue_picture2'+ext+'_'+str(sample)+'.npy')
            noprecue_pic2_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_noprecue_picture2'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_noprecue_picture3'+ext+'_'+str(sample)+'.npy')
            noprecue_pic3_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_noprecue_picture3'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_noprecue_picture4'+ext+'_'+str(sample)+'.npy')
            noprecue_pic4_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_noprecue_picture4'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_noprecue_picture5'+ext+'_'+str(sample)+'.npy')
            noprecue_pic5_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_noprecue_picture5'+ext+'_'+str(sample)+'.npy'
            pass

        try:
            d = np.load('classification_output/'+subject+'_noprecue_picture6'+ext+'_'+str(sample)+'.npy')
            noprecue_pic6_array_list_sample.append(stats.zscore(d))
        except IOError:
            print subject,"has not file",subject+'_noprecue_picture6'+ext+'_'+str(sample)+'.npy'
            pass
    pic1 = np.average(noprecue_pic1_array_list_sample, axis=0)
    pic2 = np.average(noprecue_pic2_array_list_sample, axis=0)
    pic3 = np.average(noprecue_pic3_array_list_sample, axis=0)
    pic4 = np.average(noprecue_pic4_array_list_sample, axis=0)
    pic5 = np.average(noprecue_pic5_array_list_sample, axis=0)
    pic6 = np.average(noprecue_pic6_array_list_sample, axis=0)
    
    if pic1.shape:
        noprecue_pic1_array_list.append(pic1)
    if pic2.shape:
        noprecue_pic2_array_list.append(pic2)
    if pic3.shape:
        noprecue_pic3_array_list.append(pic3)
    if pic4.shape:
        noprecue_pic4_array_list.append(pic4)
    if pic5.shape:
        noprecue_pic5_array_list.append(pic5)
    if pic6.shape:
        noprecue_pic6_array_list.append(pic6)
# Out:
# sub010 has not file sub010_noprecue_picture1_all_0.npy
# sub010 has not file sub010_noprecue_picture1_all_1.npy
# sub010 has not file sub010_noprecue_picture1_all_2.npy
# sub010 has not file sub010_noprecue_picture1_all_3.npy
# sub010 has not file sub010_noprecue_picture1_all_4.npy
# sub010 has not file sub010_noprecue_picture1_all_5.npy
# sub010 has not file sub010_noprecue_picture1_all_6.npy
# sub010 has not file sub010_noprecue_picture1_all_7.npy
# sub010 has not file sub010_noprecue_picture1_all_8.npy
# sub010 has not file sub010_noprecue_picture1_all_9.npy

# %%
a_pic1 = np.average(noprecue_pic1_array_list, axis=0)
err_pic1 = stats.sem(noprecue_pic1_array_list, axis=0)
a_pic2 = np.average(noprecue_pic2_array_list, axis=0)
err_pic2 = stats.sem(noprecue_pic2_array_list, axis=0)
a_pic3 = np.average(noprecue_pic3_array_list, axis=0)
err_pic3 = stats.sem(noprecue_pic3_array_list, axis=0)
a_pic4 = np.average(noprecue_pic4_array_list, axis=0)
err_pic4 = stats.sem(noprecue_pic4_array_list, axis=0)
a_pic5 = np.average(noprecue_pic5_array_list, axis=0)
err_pic5 = stats.sem(noprecue_pic5_array_list, axis=0)
a_pic6 = np.average(noprecue_pic6_array_list, axis=0)
err_pic6 = stats.sem(noprecue_pic6_array_list, axis=0)

# %%
y_noprecue_pic1 = a_pic1.diagonal()
y_noprecue_pic2 = a_pic2.diagonal()
y_noprecue_pic3 = a_pic3.diagonal()
y_noprecue_pic4 = a_pic4.diagonal()
y_noprecue_pic5 = a_pic5.diagonal()
y_noprecue_pic6 = a_pic6.diagonal()



plt.figure()
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic1)#, yerr=err_pic1.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic2)#, yerr=err_pic2.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic3)#, yerr=err_pic3.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic4)#, yerr=err_pic4.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic5)#, yerr=err_pic5.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic6)#, yerr=err_pic6.diagonal())
# Out:
# <Container object of 3 artists>

# %%
before = 15
after =  15

#when done for each individual subject
precue_pic1 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in precue_pic1_array_list])
precue_pic2 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in precue_pic2_array_list])
precue_pic3 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in precue_pic3_array_list])
precue_pic4 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in precue_pic4_array_list])
precue_pic5 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in precue_pic5_array_list])
precue_pic6 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in precue_pic6_array_list])

precue_pic1_interval = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after] for item in precue_pic1_array_list])
precue_pic2_interval = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after] for item in precue_pic2_array_list])
precue_pic3_interval = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after] for item in precue_pic3_array_list])
precue_pic4_interval = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after] for item in precue_pic4_array_list])
precue_pic5_interval = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after] for item in precue_pic5_array_list])
precue_pic6_interval = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after] for item in precue_pic6_array_list])



#when done for best timepoint across subjects
precue_pic1 = np.array([item.diagonal()[y_precue_pic1.argmax()-before:y_precue_pic1.argmax()+after].mean() for item in precue_pic1_array_list])
precue_pic2 = np.array([item.diagonal()[y_precue_pic2.argmax()-before:y_precue_pic2.argmax()+after].mean() for item in precue_pic2_array_list])
precue_pic3 = np.array([item.diagonal()[y_precue_pic3.argmax()-before:y_precue_pic3.argmax()+after].mean() for item in precue_pic3_array_list])
precue_pic4 = np.array([item.diagonal()[y_precue_pic4.argmax()-before:y_precue_pic4.argmax()+after].mean() for item in precue_pic4_array_list])
precue_pic5 = np.array([item.diagonal()[y_precue_pic5.argmax()-before:y_precue_pic5.argmax()+after].mean() for item in precue_pic5_array_list])
precue_pic6 = np.array([item.diagonal()[y_precue_pic6.argmax()-before:y_precue_pic6.argmax()+after].mean() for item in precue_pic6_array_list])

precue_pic1_interval = np.array([item.diagonal()[y_precue_pic1.argmax()-before:y_precue_pic1.argmax()+after] for item in precue_pic1_array_list])
precue_pic2_interval = np.array([item.diagonal()[y_precue_pic2.argmax()-before:y_precue_pic2.argmax()+after] for item in precue_pic2_array_list])
precue_pic3_interval = np.array([item.diagonal()[y_precue_pic3.argmax()-before:y_precue_pic3.argmax()+after] for item in precue_pic3_array_list])
precue_pic4_interval = np.array([item.diagonal()[y_precue_pic4.argmax()-before:y_precue_pic4.argmax()+after] for item in precue_pic4_array_list])
precue_pic5_interval = np.array([item.diagonal()[y_precue_pic5.argmax()-before:y_precue_pic5.argmax()+after] for item in precue_pic5_array_list])
precue_pic6_interval = np.array([item.diagonal()[y_precue_pic6.argmax()-before:y_precue_pic6.argmax()+after] for item in precue_pic6_array_list])



#when done for each individual subject
noprecue_pic1 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in noprecue_pic1_array_list])
noprecue_pic2 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in noprecue_pic2_array_list])
noprecue_pic3 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in noprecue_pic3_array_list])
noprecue_pic4 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in noprecue_pic4_array_list])
noprecue_pic5 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in noprecue_pic5_array_list])
noprecue_pic6 = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in noprecue_pic6_array_list])

#when done for best timepoint across subjects
noprecue_pic1 = np.array([item.diagonal()[y_noprecue_pic1.argmax()-before:y_noprecue_pic1.argmax()+after].mean() for item in noprecue_pic1_array_list])
noprecue_pic2 = np.array([item.diagonal()[y_noprecue_pic2.argmax()-before:y_noprecue_pic2.argmax()+after].mean() for item in noprecue_pic2_array_list])
noprecue_pic3 = np.array([item.diagonal()[y_noprecue_pic3.argmax()-before:y_noprecue_pic3.argmax()+after].mean() for item in noprecue_pic3_array_list])
noprecue_pic4 = np.array([item.diagonal()[y_noprecue_pic4.argmax()-before:y_noprecue_pic4.argmax()+after].mean() for item in noprecue_pic4_array_list])
noprecue_pic5 = np.array([item.diagonal()[y_noprecue_pic5.argmax()-before:y_noprecue_pic5.argmax()+after].mean() for item in noprecue_pic5_array_list])
noprecue_pic6 = np.array([item.diagonal()[y_noprecue_pic6.argmax()-before:y_noprecue_pic6.argmax()+after].mean() for item in noprecue_pic6_array_list])

noprecue_pic1_interval = np.array([item.diagonal()[y_noprecue_pic1.argmax()-before:y_noprecue_pic1.argmax()+after] for item in noprecue_pic1_array_list])
noprecue_pic2_interval = np.array([item.diagonal()[y_noprecue_pic2.argmax()-before:y_noprecue_pic2.argmax()+after] for item in noprecue_pic2_array_list])
noprecue_pic3_interval = np.array([item.diagonal()[y_noprecue_pic3.argmax()-before:y_noprecue_pic3.argmax()+after] for item in noprecue_pic3_array_list])
noprecue_pic4_interval = np.array([item.diagonal()[y_noprecue_pic4.argmax()-before:y_noprecue_pic4.argmax()+after] for item in noprecue_pic4_array_list])
noprecue_pic5_interval = np.array([item.diagonal()[y_noprecue_pic5.argmax()-before:y_noprecue_pic5.argmax()+after] for item in noprecue_pic5_array_list])
noprecue_pic6_interval = np.array([item.diagonal()[y_noprecue_pic6.argmax()-before:y_noprecue_pic6.argmax()+after] for item in noprecue_pic6_array_list])

# %%
precue_allpics = np.mean([precue_pic2,precue_pic3,precue_pic4,precue_pic5,precue_pic6],axis=0) #average across pictures so you have number per subject
noprecue_allpics = np.mean([noprecue_pic2,noprecue_pic3,noprecue_pic4,noprecue_pic5,noprecue_pic6],axis=0)

#average across pictures so you have interval persubject
precue_allpics_interval = np.mean([precue_pic2_interval,precue_pic3_interval,precue_pic4_interval,precue_pic5_interval,precue_pic6_interval],axis=0)
noprecue_allpics_interval = np.mean([noprecue_pic2_interval,noprecue_pic3_interval,noprecue_pic4_interval,noprecue_pic5_interval,noprecue_pic6_interval],axis=0)

# %%
plt.plot(np.mean(precue_allpics_interval,axis=0),color='lightgreen')
plt.plot(np.mean(noprecue_allpics_interval,axis=0),color='lightblue')
#plt.plot(np.mean(precue_target_interval,axis=0),color='green')
#plt.plot(np.mean(noprecue_target_interval,axis=0),color='blue')

# plt.plot(np.mean(noprecue_pic5_interval,axis=0))
# plt.plot(np.mean(noprecue_target_interval,axis=0))

# %%
precue_allpics
# Out:
# array([ 0.58508954,  0.36612044,  0.4743177 ,  0.33474783,  0.32828466,
#         0.5937379 ,  0.37983644,  0.73459044,  0.77456054,  0.64308249,
#         0.52958951,  0.42725984,  0.44641896,  0.98241964,  0.55791052,
#         0.61552867,  0.4506734 ])

# %%
stats.ttest_rel(precue_allpics,noprecue_allpics)
# Out:
# Ttest_relResult(statistic=1.1968770118518739, pvalue=0.24878818912856773)

# %%
precue_array_list = []
for subject in subject_list:
    try:
        d = np.load('classification_output/'+subject+'_precue_target_id'+ext+'.npy')
        precue_array_list.append(stats.zscore(d))
    except IOError:
        print subject,"does not have file"

# %%
a_precue = np.average(precue_array_list, axis=0)
err = stats.sem(precue_array_list, axis=0)

# %%
y_precue = a_precue.diagonal()
plt.figure()
plt.errorbar(x=np.array(range(len(y_precue))),y=y_precue, yerr=err.diagonal())
# Out:
# <Container object of 3 artists>

# %%
noprecue_array_list = []
for subject in subject_list:
    try:
        d = np.load('classification_output/'+subject+'_noprecue_target_id'+ext+'.npy')
        noprecue_array_list.append(stats.zscore(d))
    except IOError:
        print subject,"does not have file"

# %%
a_noprecue = np.average(noprecue_array_list, axis=0)
err = stats.sem(noprecue_array_list, axis=0)

# %%
y_noprecue = a_noprecue.diagonal()
plt.figure()
plt.errorbar(x=np.array(range(len(y_noprecue))),y=y_noprecue, yerr=err.diagonal())
# Out:
# <Container object of 3 artists>

# %%
len(y_noprecue)
# Out:
# 261

# %%
plt.figure()
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic1)#, yerr=err_pic1.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic2)#, yerr=err_pic2.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic3)#, yerr=err_pic3.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic4)#, yerr=err_pic4.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic5)#, yerr=err_pic5.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_precue_pic6)#, yerr=err_pic6.diagonal())

plt.errorbar(x=np.array(range(-30,91)),y=y_precue[:len(y_precue_pic1)],color='red')#, yerr=err_pic6.diagonal())
# Out:
# <Container object of 3 artists>

# %%
plt.figure()
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic1)#, yerr=err_pic1.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic2)#, yerr=err_pic2.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic3)#, yerr=err_pic3.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic4)#, yerr=err_pic4.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic5)#, yerr=err_pic5.diagonal())
plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue_pic6)#, yerr=err_pic6.diagonal())

plt.errorbar(x=np.array(range(-30,91)),y=y_noprecue[:len(y_noprecue_pic1)],color='red')#, yerr=err_pic6.diagonal())
# Out:
# <Container object of 3 artists>

# %%
a = [item.diagonal()[y_noprecue.argmax()] for item in noprecue_array_list]
b = [item.diagonal()[y_precue.argmax()] for item in precue_array_list]

c = [item.diagonal()[y_precue_pic6.argmax()] for item in precue_pic6_array_list]
d = [item.diagonal()[y_noprecue_pic6.argmax()] for item in noprecue_pic6_array_list]


print len(a),len(b)
print stats.ttest_rel(a,b)
# Out:
# 17 17
# Ttest_relResult(statistic=-0.42989236931829894, pvalue=0.67300768488720675)

# %%
before = 15
after =  15

#when done for each individual subject
precue_target = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in precue_array_list])
noprecue_target = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after].mean() for item in noprecue_array_list])

#don't take mean over the before to after interval
precue_target_interval = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after] for item in precue_array_list])
noprecue_target_interval = np.array([item.diagonal()[item.diagonal().argmax()-before:item.diagonal().argmax()+after] for item in noprecue_array_list])




#when done for best timepoint across subjects
precue_target = np.array([item.diagonal()[y_precue.argmax()-before:y_precue.argmax()+after].mean() for item in precue_array_list])
noprecue_target = np.array([item.diagonal()[y_noprecue.argmax()-before:y_noprecue.argmax()+after].mean() for item in noprecue_array_list])

#don't take mean over the before to after interval
precue_target_interval = np.array([item.diagonal()[y_precue.argmax()-before:y_precue.argmax()+after] for item in precue_array_list])
noprecue_target_interval = np.array([item.diagonal()[y_noprecue.argmax()-before:y_noprecue.argmax()+after] for item in noprecue_array_list])



# #when done for best timepoint across subjects, restricting it to specific range
# precue_target = np.array([item.diagonal()[y_precue[0:50].argmax()-before:y_precue[0:50].argmax()+after].mean() for item in precue_array_list])
# noprecue_target = np.array([item.diagonal()[y_noprecue[0:50].argmax()-before:y_noprecue[0:50].argmax()+after].mean() for item in noprecue_array_list])

# #don't take mean over the before to after interval
# precue_target_interval = np.array([item.diagonal()[y_precue[0:50].argmax()-before:y_precue[0:50].argmax()+after] for item in precue_array_list])
# noprecue_target_interval = np.array([item.diagonal()[y_noprecue[0:50].argmax()-before:y_noprecue[0:50].argmax()+after] for item in noprecue_array_list])

# %%
plt.plot(np.mean(precue_target_interval,axis=0),color="red")
plt.plot(np.mean(noprecue_target_interval,axis=0))

# %%
stats.ttest_rel(precue_target,noprecue_target)
# Out:
# Ttest_relResult(statistic=1.383721268570304, pvalue=0.18544525531515688)

# %%
diff_targ = precue_target - noprecue_target

# %%
plt.plot(np.mean(precue_allpics_interval,axis=0),color='lightgreen')
plt.plot(np.mean(noprecue_allpics_interval,axis=0),color='lightblue')
plt.plot(np.mean(precue_target_interval,axis=0),color='green')
plt.plot(np.mean(noprecue_target_interval,axis=0),color='blue')

# plt.plot(np.mean(noprecue_pic5_interval,axis=0))
# plt.plot(np.mean(noprecue_target_interval,axis=0))

# %%
stats.ttest_rel(noprecue_target,noprecue_allpics)
# Out:
# Ttest_relResult(statistic=-1.1792892473013894, pvalue=0.25552222866046381)

# %%
stats.ttest_rel(precue_target,precue_allpics)
# Out:
# Ttest_relResult(statistic=-0.14710930709999351, pvalue=0.88488348380201609)

# %%
diff_dist = precue_allpics - noprecue_allpics

# %%
stats.ttest_rel(diff_targ,diff_dist)
# Out:
# Ttest_relResult(statistic=1.0557887877426004, pvalue=0.30674681644527979)
